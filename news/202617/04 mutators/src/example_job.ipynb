# %%
# Read all parameters injected by the bundle mutator
params = [
    "target",
    "business_domain",
    "catalog",
    "bronze_schema",
    "silver_schema",
    "gold_schema",
    "ingestion_bucket",
]

values = {}
for p in params:
    values[p] = dbutils.widgets.get(p)

print(values)
