-- %%
DROP CONNECTION IF EXISTS click_house;

CREATE CONNECTION click_house TYPE JDBC
OPTIONS (
  url 'jdbc:clickhouse://ksdm80f2vi.westus3.azure.clickhouse.cloud:8443?user=default&password=3~JvFsszRXKVB&ssl=true'
);

DESCRIBE CONNECTION click_house;
