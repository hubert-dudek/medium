-- %% [markdown]
-- Literal string coalescing

-- %%
CREATE EXTERNAL TABLE hub.default.demo_ex (raw STRING)
USING DELTA
LOCATION 'abfss://unity@westus2uc.dfs.core.windows.net/'
         'landing/'
         'app1/'
         '2026/01/054/';

-- %% [markdown]
-- Parameter markers

-- %%
EXECUTE IMMEDIATE
  'CREATE VIEW main.tmp.v_para AS
   SELECT :val AS c1, :val * 2 AS c2'
USING 10 AS val;

-- %%
COMMENT ON TABLE demo_ex IS :comment;

-- %%
CREATE TABLE t_defaults (
  c1 INT DEFAULT :def
)
TBLPROPERTIES('delta.feature.allowColumnDefaults' = 'supported');

-- %% [markdown]
-- Identifiers

-- %%
SELECT 1 AS IDENTIFIER(:alias_name);

-- %%
CREATE TABLE t_ident_col (
  IDENTIFIER(:pk) BIGINT NOT NULL,
  payload STRING
);

-- %%
SELECT * FROM IDENTIFIER('default.' :table_name);
