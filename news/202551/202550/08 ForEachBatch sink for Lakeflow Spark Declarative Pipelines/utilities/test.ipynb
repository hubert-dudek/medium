# %%
    df = spark.read.table("hub.default.bronze_events")
    
    (df.write
        .format("postgresql")
        .option("url", "jdbc:postgresql://ep-bitter-mouse-d12j2fo9.database.us-west-2.cloud.databricks.com/databricks_postgres?user=hdude2020%40gmail.com&sslmode=require&channelBinding=require")
        .option("dbtable", "public.events_audited")
        .save())
