-- %% [markdown]
-- 18.1 :-)

-- %%
CREATE OR REPLACE TABLE customers (customer_id long, customer_name string);
INSERT INTO customers
(customer_id, customer_name)
VALUES (1000, 'John Doe'), (1001, 'Jane Smith');

-- %%
INSERT INTO customers
SELECT
  1002 AS customer_id,
  'Jack Smith' AS customer_name,
  'USA' AS customer_country;

-- %%
INSERT WITH SCHEMA EVOLUTION INTO customers
SELECT
  1002 AS customer_id,
  'Jack Smith' AS customer_name,
  'USA' AS customer_country;
