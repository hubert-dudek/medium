# %% [markdown]
# There are more and more sources under Lakehouse Federation, and the most recent addition is Teradata. Thanks to this, you can migrate Teradata more easily to Databricks by first federating it and then using that federation option to compare data sets with those generated by Databricks.

# %% [markdown]
# <img src="./images/teradata.png" alt="teradata.png" width="400px">
