-- %%
DROP TABLE hub.default.migrateme;

-- %%
CREATE OR REPLACE TABLE hub.default.migrateme (
  order_id     BIGINT,
  customer_id  BIGINT,
  order_ts     TIMESTAMP,
  total_amt    DECIMAL(12,2)
)
LOCATION "abfss://unity@westus2uc.dfs.core.windows.net/migrateme"

-- %%
INSERT INTO hub.default.migrateme (order_id, customer_id, order_ts, total_amt) VALUES
  (1001, 501, '2025-10-10 09:15:00', 250.00),
  (1002, 502, '2025-10-10 10:30:00', 125.50),
  (1003, 503, '2025-10-11 14:45:00', 300.75);

-- %%
DESCRIBE EXTENDED hub.default.migrateme;

-- %%
ALTER TABLE hub.default.migrateme SET MANAGED;

-- %%
DESCRIBE EXTENDED hub.default.migrateme;
