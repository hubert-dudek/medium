# %% [markdown]
# https://github.com/databricks/cli/pull/4201

# %%
# %sh
..\cli\v0.281.0\databricks.exe bundle plan --output json > 281.json

# %%
# %sh
..\cli\v0.282.0\databricks.exe bundle plan --output json > 282.json
