-- %%
CREATE TABLE customer_source (
    customer_id         BIGINT PRIMARY KEY,
    customer_name       TEXT NOT NULL,
    email               TEXT,
    country_code        TEXT,
    last_modified_ts    TIMESTAMP NOT NULL,
    is_deleted          BOOLEAN NOT NULL DEFAULT FALSE
);
INSERT INTO customer_source (
    customer_id,
    customer_name,
    email,
    country_code,
    last_modified_ts,
    is_deleted
)
VALUES
    (1, 'Alice Johnson',  'alice@example.com',   'US', '2026-04-20 09:15:00', FALSE),
    (2, 'Bob Smith',      'bob@example.com',     'DE', '2026-04-20 09:20:00', FALSE),
    (3, 'Charlie Brown',  'charlie@example.com', 'PL', '2026-04-20 09:25:00', FALSE),
    (4, 'Diana Miller',   'diana@example.com',   'CZ', '2026-04-20 09:30:00', TRUE),
    (5, 'Ethan Davis',    'ethan@example.com',   'SK', '2026-04-20 09:35:00', FALSE);
