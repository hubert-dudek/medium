-- %%
CREATE OR REPLACE TABLE my_void (
  id INT,
  v VOID,
  name STRING);

-- %%
INSERT INTO
  my_void
VALUES
  (1, NULL, 'a');

-- %%
SELECT
  *
FROM
  my_void;

-- %%
INSERT INTO my_void
  VALUES (1, NULL, 'a')

-- %%
INSERT INTO my_void
  VALUES (1, 'test', 'a')
