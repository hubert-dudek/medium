-- %%
-- Step 1: Create a simple test function
CREATE OR REPLACE FUNCTION hub.default.convert_celsius(temp_c DOUBLE)
RETURNS DOUBLE
RETURN (temp_c * 9.0 / 5.0) + 32.0;

-- %%
UNSET TAG ON FUNCTION hub.default.convert_celsius `marketing`;

-- %%
-- Step 3: Verify the tags were applied
SELECT *
FROM hub.information_schema.routine_tags
WHERE routine_name = 'convert_celsius_to_fahrenheit';
