-- %%
SELECT
  *
FROM
  workspace.default.sales
WHERE
  country_id
    = (
      SELECT
        country_id
      FROM
        countries
      WHERE
        country_name = :country
      LIMIT 1
    )
