# %%
# %sql
EXECUTE IMMEDIATE 'OPTIMIZE ' || :auto_cdc_standard_table;
EXECUTE IMMEDIATE 'OPTIMIZE ' || :auto_cdc_performance_table;
EXECUTE IMMEDIATE 'OPTIMIZE ' || :structured_streaming_standard_table;
EXECUTE IMMEDIATE 'OPTIMIZE ' || :structured_streaming_performance_table;
EXECUTE IMMEDIATE 'OPTIMIZE ' || :table_changes_table;
