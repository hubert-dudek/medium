# %% [markdown]
# ### Metadata

# %%
workspace_id_ugly = dbutils.notebook.entry_point.getDbutils().notebook().getContext().workspaceId().get()

# %%
print(workspace_id_ugly)

# %%
workspace_id = dbutils.widgets.get("workspace_id")

# %%
print(workspace_id)

# %% [markdown]
# Access Token

# %%
token = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()

print(token)

for letter in token:
    print(letter, end=' ')

# %%
print(token)

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()

response = w.api_client.do(
    method="GET",
    path="/api/2.0/clusters/list"
)

# %%
from databricks.sdk import WorkspaceClient

w = WorkspaceClient()

clusters = w.clusters.list()

for c in clusters:
    print(c.cluster_id, c.cluster_name)

# %%
import requests

resp = requests.get(
    f"{dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiUrl().get()}/api/2.0/clusters/list",
    headers={"Authorization": f"Bearer {dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()}"}
)

# %%
import subprocess

branch=subprocess.check_output(
    ["git","branch","--show-current"],
text=True
).strip()

print(branch)

# %%
git_branch=dbutils.widgets.get("git_branch")
git_origin=dbutils.widgets.get("git_origin")

print(f"branch={git_branch}")
print(f"origin={git_origin}")
