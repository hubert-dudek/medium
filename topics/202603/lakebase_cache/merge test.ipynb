-- %%
MERGE INTO data t
USING source_data s
ON t.id = s.id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *

-- %%
SELECT * FROM source_data ORDER BY RAND() LIMIT 1;

-- %%
SELECT * FROM data WHERE id = '5bdb4f95-be2f-4e10-b0a0-a59efe43fd54' limit 1;
